# %% [markdown]
# # Preprocesamiento

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys

sys.path.append('..')
from utils.outliers_Tukey import outliers_Tukey, graficar_outliers

# %%
df = pd.read_csv('../datos/demanda_electricidad_california_2019_2025.csv',
                parse_dates = ['period'])
df
# Out:
#                     period subba                           subba-name parent  \
# 0      2019-01-01 00:00:00  PGAE             Pacific Gas and Electric   CISO
# 1      2019-01-01 00:00:00   SCE    Southern California Edison - CISO   CISO
# 2      2019-01-01 00:00:00  SDGE    San Diego Gas and Electric - CISO   CISO
# 3      2019-01-01 00:00:00   VEA  Valley Electric Association  - CISO   CISO
# 4      2019-01-01 01:00:00  PGAE             Pacific Gas and Electric   CISO
# ...                    ...   ...                                  ...    ...
# 229140 2025-07-19 23:00:00   SCE           Southern California Edison   CISO
# 229141 2025-07-20 00:00:00  PGAE             Pacific Gas and Electric   CISO
# 229142 2025-07-20 00:00:00   SCE           Southern California Edison   CISO
# 229143 2025-07-20 00:00:00  SDGE           San Diego Gas and Electric   CISO
# 229144 2025-07-20 00:00:00   VEA          Valley Electric Association   CISO
#
#                                    parent-name  value    value-units
# 0       California Independent System Operator  10440  megawatthours
# 1       California Independent System Operator  10287  megawatthours
# 2       California Independent System Operator   2414  megawatthours
# 3       California Independent System Operator     75  megawatthours
# 4       California Independent System Operator  11256  megawatthours
# ...                                        ...    ...            ...
# 229140  California Independent System Operator  13931  megawatthours
# 229141  California Independent System Operator  11336  megawatthours
# 229142  California Independent System Operator  14393  megawatthours
# 229143  California Independent System Operator   1491  megawatthours
# 229144  California Independent System Operator    124  megawatthours
#
# [229145 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 229145 entries, 0 to 229144
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   period       229145 non-null  datetime64[us]
#  1   subba        229145 non-null  str
#  2   subba-name   229145 non-null  str
#  3   parent       229145 non-null  str
#  4   parent-name  229145 non-null  str
#  5   value        229145 non-null  int64
#  6   value-units  229145 non-null  str
# dtypes: datetime64[us](1), int64(1), str(5)
# memory usage: 12.2 MB

# %% [markdown]
# ## Agregación de periodos por suma de valores

# %%
df_gr = df.groupby('period')['value'].sum()
df_gr = df_gr.sort_index(ascending = True)
df_gr = pd.DataFrame(df_gr)
df_gr.head()
# Out:
#                      value
# period
# 2019-01-01 00:00:00  23216
# 2019-01-01 01:00:00  24947
# 2019-01-01 02:00:00  27655
# 2019-01-01 03:00:00  27676
# 2019-01-01 04:00:00  26853

# %% [markdown]
# ## Marcas de tiempo faltantes

# %% [markdown]
# #### 1. Observaciónes faltantes (valores NaN en la serie)

# %%
# indice ideal
indice_completo = pd.date_range(start = df_gr.index.min(), end = df_gr.index.max(), freq = 'h')

df_full = df_gr.reindex(indice_completo)

marcas_faltantes = df_full[df_full['value'].isna()]
print(f'indices faltantes: {len(marcas_faltantes)}') # valores NaN
# Out:
# indices faltantes: 118

# %%
# Crear máscara con marcas de tiempo faltantes
mascara_faltantes = df_full['value'].isna()

# Graficar serie de tiempo (en azul)
fig, ax = plt.subplots(1,figsize=(12,5))
sns.lineplot(df_full, ax=ax)

# Graficar las marcas faltantes como líneas verticales en rojo
ymin = df_full['value'].min()
ymax = df_full['value'].max()
for ts in marcas_faltantes.index:
    ax.vlines(ts, ymin, ymax, colors='red', linestyles='dashed', linewidth=0.5)

ax.set_xlabel('Tiempo')
ax.set_ylabel('Demanda MWH')
ax.set_title('Serie de tiempo interpolada')
# Out:
# Text(0.5, 1.0, 'Serie de tiempo interpolada')

# %% [markdown]
# Las distribuciónes son aleatorias y no en bloques, por lo que se puede imputar interpolando

# %% [markdown]
# ## Interpolación

# %%
df_interpol = df_full.interpolate(method = 'linear')

fig, ax = plt.subplots(1,figsize=(15, 8))
sns.lineplot(df_interpol, ax=ax)
ax.grid()
ax.set_xlabel('Fecha-hora')
ax.set_ylabel('Demanda (MWH)')
ax.set_title('Serie de tiempo interpolada')
# Out:
# Text(0.5, 1.0, 'Serie de tiempo interpolada')

# %%
print(f'datos faltantes: {df_interpol.isna().sum()}')
# Out:
# datos faltantes: value    0
# dtype: int64

# %% [markdown]
# ## Indice temporal

# %% [markdown]
# Todo debe estar consecutivametne registrado exactamente cada hora

# %%
time_diffs = df_interpol.index.to_series().diff().dt.total_seconds()
time_diffs.describe()
# Out:
# count    57408.0
# mean      3600.0
# std          0.0
# min       3600.0
# 25%       3600.0
# 50%       3600.0
# 75%       3600.0
# max       3600.0
# dtype: float64

# %%
df_interpol
# Out:
#                        value
# 2019-01-01 00:00:00  23216.0
# 2019-01-01 01:00:00  24947.0
# 2019-01-01 02:00:00  27655.0
# 2019-01-01 03:00:00  27676.0
# 2019-01-01 04:00:00  26853.0
# ...                      ...
# 2025-07-19 20:00:00  29380.0
# 2025-07-19 21:00:00  27763.0
# 2025-07-19 22:00:00  26659.0
# 2025-07-19 23:00:00  26438.0
# 2025-07-20 00:00:00  27344.0
#
# [57409 rows x 1 columns]

# %% [markdown]
# ## Detección de valores extremos

# %% [markdown]
# Hay que hacer énfasis unicamente en los valores bajos

# %%
# Visualización
outliers = outliers_Tukey(df_interpol)
graficar_outliers(df_interpol, 'Tiempo', 'Demanda (MWH)', outliers)
# Out:
# Hay 7 outliers

# %% [markdown]
# Limpiar los Outliers

# %%
idx = df_interpol.index.isin(outliers.index)
df_interpol.iloc[idx] = None

df_interpol = df_interpol.interpolate(method = 'linear')

fig, ax = plt.subplots(1 , figsize=(15, 8))
sns.lineplot(df_interpol, ax=ax)
ax.grid()
ax.set_xlabel('Fecha-hora')
ax.set_ylabel('Demanda (MWH)')
ax.set_title('Serie de tiempo interpolada sin outliers')
# Out:
# Text(0.5, 1.0, 'Serie de tiempo interpolada sin outliers')
